# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
intents_file = open('/home/iba/Music/wfh/chatbot/intents.json').read()
intents = json.loads(intents_file)
# Out:
# Using TensorFlow backend.

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:

    for pattern in intent['patterns']:

        #tokenize each word

        word = nltk.word_tokenize(pattern)

        words.extend(word)        

        #add documents in the corpus

        documents.append((word, intent['tag']))

        # add to our classes list

        if intent['tag'] not in classes:

            classes.append(intent['tag'])


print(documents)
# Out:
# [([u'Hi', u'there'], u'greeting'), ([u'How', u'are', u'you'], u'greeting'), ([u'Is', u'anyone', u'there', u'?'], u'greeting'), ([u'Hey'], u'greeting'), ([u'Hola'], u'greeting'), ([u'Hello'], u'greeting'), ([u'Good', u'day'], u'greeting'), ([u'Bye'], u'goodbye'), ([u'See', u'you', u'later'], u'goodbye'), ([u'Goodbye'], u'goodbye'), ([u'Nice', u'chatting', u'to', u'you', u',', u'bye'], u'goodbye'), ([u'Till', u'next', u'time'], u'goodbye'), ([u'Thanks'], u'thanks'), ([u'Thank', u'you'], u'thanks'), ([u'That', u"'s", u'helpful'], u'thanks'), ([u'Awesome', u',', u'thanks'], u'thanks'), ([u'Thanks', u'for', u'helping', u'me'], u'thanks'), ([u'How', u'you', u'could', u'help', u'me', u'?'], u'options'), ([u'What', u'you', u'can', u'do', u'?'], u'options'), ([u'What', u'help', u'you', u'provide', u'?'], u'options'), ([u'How', u'you', u'can', u'be', u'helpful', u'?'], u'options'), ([u'What', u'support', u'is', u'offered'], u'options'), ([u'How', u'to', u'check', u'Adverse', u'drug', u'reaction', u'?'], u'adverse_drug'), ([u'Open', u'adverse', u'drugs', u'module'], u'adverse_drug'), ([u'Give', u'me', u'a', u'list', u'of', u'drugs', u'causing', u'adverse', u'behavior'], u'adverse_drug'), ([u'List', u'all', u'drugs', u'suitable', u'for', u'patient', u'with', u'adverse', u'reaction'], u'adverse_drug'), ([u'Which', u'drugs', u'dont', u'have', u'adverse', u'reaction', u'?'], u'adverse_drug'), ([u'Open', u'blood', u'pressure', u'module'], u'blood_pressure'), ([u'Task', u'related', u'to', u'blood', u'pressure'], u'blood_pressure'), ([u'Blood', u'pressure', u'data', u'entry'], u'blood_pressure'), ([u'I', u'want', u'to', u'log', u'blood', u'pressure', u'results'], u'blood_pressure'), ([u'Blood', u'pressure', u'data', u'management'], u'blood_pressure'), ([u'I', u'want', u'to', u'search', u'for', u'blood', u'pressure', u'result', u'history'], u'blood_pressure_search'), ([u'Blood', u'pressure', u'for', u'patient'], u'blood_pressure_search'), ([u'Load', u'patient', u'blood', u'pressure', u'result'], u'blood_pressure_search'), ([u'Show', u'blood', u'pressure', u'results', u'for', u'patient'], u'blood_pressure_search'), ([u'Find', u'blood', u'pressure', u'results', u'by', u'ID'], u'blood_pressure_search'), ([u'Find', u'me', u'a', u'pharmacy'], u'pharmacy_search'), ([u'Find', u'pharmacy'], u'pharmacy_search'), ([u'List', u'of', u'pharmacies', u'nearby'], u'pharmacy_search'), ([u'Locate', u'pharmacy'], u'pharmacy_search'), ([u'Search', u'pharmacy'], u'pharmacy_search'), ([u'Lookup', u'for', u'hospital'], u'hospital_search'), ([u'Searching', u'for', u'hospital', u'to', u'transfer', u'patient'], u'hospital_search'), ([u'I', u'want', u'to', u'search', u'hospital', u'data'], u'hospital_search'), ([u'Hospital', u'lookup', u'for', u'patient'], u'hospital_search'), ([u'Looking', u'up', u'hospital', u'details'], u'hospital_search')]

# %%
# lemmaztize and lower each word and remove duplicates

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]

words = sorted(list(set(words)))

# sort classes

classes = sorted(list(set(classes)))

# documents = combination between patterns and intents

print (len(documents), "documents")

# classes = intents

print (len(classes), "classes", classes)

# words = all words, vocabulary

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))

pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# (47, 'documents')
# (9, 'classes', [u'adverse_drug', u'blood_pressure', u'blood_pressure_search', u'goodbye', u'greeting', u'hospital_search', u'options', u'pharmacy_search', u'thanks'])
# (87, 'unique lemmatized words', [u"'s", u'a', u'adverse', u'all', u'anyone', u'are', u'awesome', u'be', u'behavior', u'blood', u'by', u'bye', u'can', u'causing', u'chatting', u'check', u'could', u'data', u'day', u'detail', u'do', u'dont', u'drug', u'entry', u'find', u'for', u'give', u'good', u'goodbye', u'have', u'hello', u'help', u'helpful', u'helping', u'hey', u'hi', u'history', u'hola', u'hospital', u'how', u'i', u'id', u'is', u'later', u'list', u'load', u'locate', u'log', u'looking', u'lookup', u'management', u'me', u'module', u'nearby', u'next', u'nice', u'of', u'offered', u'open', u'patient', u'pharmacy', u'pressure', u'provide', u'reaction', u'related', u'result', u'search', u'searching', u'see', u'show', u'suitable', u'support', u'task', u'thank', u'thanks', u'that', u'there', u'till', u'time', u'to', u'transfer', u'up', u'want', u'what', u'which', u'with', u'you'])

# %%
# create the training data

training = []

# create empty array for the output

output_empty = [0] * len(classes)

# training set, bag of words for every sentence

for doc in documents:

    # initializing bag of words

    bag = []

    # list of tokenized words for the pattern

    word_patterns = doc[0]

    # lemmatize each word - create base word, in attempt to represent related words

    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]

    # create the bag of words array with 1, if word is found in current pattern

    for word in words:

        bag.append(1) if word in word_patterns else bag.append(0)

        

    # output is a '0' for each tag and '1' for current tag (for each pattern)

    output_row = list(output_empty)

    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# shuffle the features and make numpy array

random.shuffle(training)

training = np.array(training)

# create training and testing lists. X - patterns, Y - intents

train_x = list(training[:,0])

train_y = list(training[:,1])

print("Training data is created")
# Out:
# Training data is created

# %%
# deep neural networds model

model = Sequential()

model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(len(train_y[0]), activation='softmax'))

# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#Training and saving the model 

hist = model.fit(np.array(train_x), np.array(train_y), epochs=20, batch_size=5, verbose=1)

model.save('chatbot_model.h5', hist)


print("model is created")
# Out:
# Epoch 1/20
# 47/47 [==============================] - 0s 6ms/step - loss: 2.2657 - accuracy: 0.0851
# Epoch 2/20
# 47/47 [==============================] - 0s 670us/step - loss: 2.1680 - accuracy: 0.1702
# Epoch 3/20
# 47/47 [==============================] - 0s 689us/step - loss: 2.1232 - accuracy: 0.1702
# Epoch 4/20
# 47/47 [==============================] - 0s 688us/step - loss: 2.0254 - accuracy: 0.3191
# Epoch 5/20
# 47/47 [==============================] - 0s 626us/step - loss: 1.9007 - accuracy: 0.4043
# Epoch 6/20
# 47/47 [==============================] - 0s 666us/step - loss: 1.8410 - accuracy: 0.4681
# Epoch 7/20
# 47/47 [==============================] - 0s 820us/step - loss: 1.7025 - accuracy: 0.4894
# Epoch 8/20
# 47/47 [==============================] - 0s 794us/step - loss: 1.5319 - accuracy: 0.5745
# Epoch 9/20
# 47/47 [==============================] - 0s 712us/step - loss: 1.4701 - accuracy: 0.6596
# Epoch 10/20
# 47/47 [==============================] - 0s 502us/step - loss: 1.3019 - accuracy: 0.7021
# Epoch 11/20
# 47/47 [==============================] - 0s 680us/step - loss: 1.0874 - accuracy: 0.7872
# Epoch 12/20
# 47/47 [==============================] - 0s 740us/step - loss: 1.0285 - accuracy: 0.7872
# Epoch 13/20
# 47/47 [==============================] - 0s 583us/step - loss: 0.9896 - accuracy: 0.7872
# Epoch 14/20
# 47/47 [==============================] - 0s 543us/step - loss: 0.8945 - accuracy: 0.7021
# Epoch 15/20
# 47/47 [==============================] - 0s 629us/step - loss: 0.8217 - accuracy: 0.7660
# Epoch 16/20
# 47/47 [==============================] - 0s 563us/step - loss: 0.7490 - accuracy: 0.8085
# Epoch 17/20
# 47/47 [==============================] - 0s 568us/step - loss: 0.8182 - accuracy: 0.7447
# Epoch 18/20
# 47/47 [==============================] - 0s 570us/step - loss: 0.6654 - accuracy: 0.8511
# Epoch 19/20
# 47/47 [==============================] - 0s 595us/step - loss: 0.5250 - accuracy: 0.8511
# Epoch 20/20
# 47/47 [==============================] - 0s 579us/step - loss: 0.6016 - accuracy: 0.8511
# model is created

# %%
import nltk

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

import pickle

import numpy as np

from keras.models import load_model

model = load_model('chatbot_model.h5')

import json

import random

intents = json.loads(open('/home/iba/Music/wfh/chatbot/intents.json').read())

words = pickle.load(open('words.pkl','rb'))

classes = pickle.load(open('classes.pkl','rb'))

def clean_up_sentence(sentence):

    # tokenize the pattern - splitting words into array

    sentence_words = nltk.word_tokenize(sentence)

    # stemming every word - reducing to base form

    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]

    return sentence_words

# return bag of words array: 0 or 1 for words that exist in sentence

def bag_of_words(sentence, words, show_details=True):

    # tokenizing patterns

    sentence_words = clean_up_sentence(sentence)

    # bag of words - vocabulary matrix

    bag = [0]*len(words)  
    for s in sentence_words:

        for i,word in enumerate(words):

            if word == s: 

                # assign 1 if current word is in the vocabulary position

                bag[i] = 1

                if show_details:

                    print ("found in bag: %s" % word)

    return(np.array(bag))

def predict_class(sentence):

    # filter below  threshold predictions

    p = bag_of_words(sentence, words,show_details=False)

    res = model.predict(np.array([p]))[0]

    ERROR_THRESHOLD = 0.25

    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]

    # sorting strength probability

    results.sort(key=lambda x: x[1], reverse=True)

    return_list = []

    for r in results:

        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})

    return return_list

def getResponse(ints, intents_json):

    tag = ints[0]['intent']

    list_of_intents = intents_json['intents']

    for i in list_of_intents:

        if(i['tag']== tag):

            result = random.choice(i['responses'])

            break

    return result

#Creating tkinter GUI

import tkinter

from tkinter import *

def send():

    msg = EntryBox.get("1.0",'end-1c').strip()

    EntryBox.delete("0.0",END)

    if msg != '':

        ChatBox.config(state=NORMAL)

        ChatBox.insert(END, "You: " + msg + '\n\n')

        ChatBox.config(foreground="#446665", font=("Verdana", 12 )) 


        ints = predict_class(msg)

        res = getResponse(ints, intents)

        

        ChatBox.insert(END, "Bot: " + res + '\n\n')           


        ChatBox.config(state=DISABLED)

        ChatBox.yview(END)

root = Tk()

root.title("Chatbot")

root.geometry("400x500")

root.resizable(width=FALSE, height=FALSE)

#Create Chat window

ChatBox = Text(root, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatBox.config(state=DISABLED)

#Bind scrollbar to Chat window

scrollbar = Scrollbar(root, command=ChatBox.yview, cursor="heart")

ChatBox['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(root, font=("Verdana",12,'bold'), text="Send", width="12", height=5,

                    bd=0, bg="#f9a602", activebackground="#3c9d9b",fg='#000000',
                    command= send )

#Create the box to enter message

EntryBox = Text(root, bd=0, bg="white",width="29", height="5", font="Arial")

#EntryBox.bind("<Return>", send)

#Place all components on the screen

scrollbar.place(x=376,y=6, height=386)

ChatBox.place(x=6,y=6, height=386, width=370)

EntryBox.place(x=128, y=401, height=90, width=265)

SendButton.place(x=6, y=401, height=90)

root.mainloop()
